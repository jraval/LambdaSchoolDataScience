# %% [markdown]
# <a href="https://colab.research.google.com/github/jraval/LambdaSchoolDataScience/blob/master/JRDSPT10_1_21_2021_Copy_of_LS_DS_214_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 1, Module 4*
#
# ---

# %% [markdown]
# # Logistic Regression
#
#
# ## Assignment 🌯
#
# You'll use a [**dataset of 400+ burrito reviews**](https://srcole.github.io/100burritos/). How accurately can you predict whether a burrito is rated 'Great'?
#
# > We have developed a 10-dimensional system for rating the burritos in San Diego. ... Generate models for what makes a burrito great and investigate correlations in its dimensions.
#
# - [x ] Do train/validate/test split. Train on reviews from 2016 & earlier. Validate on 2017. Test on 2018 & later.
# - [x ] Begin with baselines for classification.
# - [x ] Use scikit-learn for logistic regression.
# - [ x] Get your model's validation accuracy. (Multiple times if you try multiple iterations.)
# - [x ] Get your model's test accuracy. (One time, at the end.)
# - [x ] Commit your notebook to your fork of the GitHub repo.
#
#
# ## Stretch Goals
#
# - [ ] Add your own stretch goal(s) !
# - [ x] Make exploratory visualizations.
# - [ x] Do one-hot encoding.
# - [ ] Do [feature scaling](https://scikit-learn.org/stable/modules/preprocessing.html).
# - [ ] Get and plot your coefficients.
# - [x ] Try [scikit-learn pipelines](https://scikit-learn.org/stable/modules/compose.html).

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Linear-Models/master/data/'
    # !pip install category_encoders==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'

# %%
# Load data downloaded from https://srcole.github.io/100burritos/
import pandas as pd
df = pd.read_csv(DATA_PATH+'burritos/burritos.csv', parse_dates=['Date'], index_col=['Date'])

# %%
df
# Out:
#                             Location        Burrito  ... Corn Zucchini
# Date                                                 ...
# 2016-01-18        Donato's taco shop    California   ...  NaN      NaN
# 2016-01-24      Oscar's Mexican food    California   ...  NaN      NaN
# 2016-01-24      Oscar's Mexican food       Carnitas  ...  NaN      NaN
# 2016-01-24      Oscar's Mexican food    Carne asada  ...  NaN      NaN
# 2016-01-27              Pollos Maria     California  ...  NaN      NaN
# ...                              ...            ...  ...  ...      ...
# 2019-08-27  Valentine's Mexican Food      Al Pastor  ...  NaN      NaN
# 2019-08-27  Valentine's Mexican Food  Chile Relleno  ...  NaN      NaN
# 2019-08-27  Valentine's Mexican Food     California  ...  NaN      NaN
# 2019-08-27  Valentine's Mexican Food         Shrimp  ...  NaN      NaN
# 2019-08-27  Valentine's Mexican Food    Pollo Asado  ...  NaN      NaN
#
# [423 rows x 65 columns]

# %%
df.describe()
# Out:
#             Yelp     Google        Cost  ...        Wrap     overall  Queso
# count  87.000000  87.000000  416.000000  ...  420.000000  421.000000    0.0
# mean    3.887356   4.167816    7.065216  ...    3.981190    3.620887    NaN
# std     0.475396   0.373698    1.503645  ...    1.115803    0.755718    NaN
# min     2.500000   2.900000    2.990000  ...    0.000000    1.000000    NaN
# 25%     3.500000   4.000000    6.250000  ...    3.500000    3.100000    NaN
# 50%     4.000000   4.200000    6.990000  ...    4.000000    3.800000    NaN
# 75%     4.000000   4.400000    7.860000  ...    5.000000    4.100000    NaN
# max     4.500000   5.000000   25.000000  ...    5.000000    5.000000    NaN
#
# [8 rows x 20 columns]

# %%
# Derive binary classification target:
# We define a 'Great' burrito as having an
# overall rating of 4 or higher, on a 5 point scale.
# Drop unrated burritos.
df = df.dropna(subset=['overall'])
df['Great'] = df['overall'] >= 4
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Clean/combine the Burrito categories
df['Burrito'] = df['Burrito'].str.lower()

california = df['Burrito'].str.contains('california')
asada = df['Burrito'].str.contains('asada')
surf = df['Burrito'].str.contains('surf')
carnitas = df['Burrito'].str.contains('carnitas')

df.loc[california, 'Burrito'] = 'California'
df.loc[asada, 'Burrito'] = 'Asada'
df.loc[surf, 'Burrito'] = 'Surf & Turf'
df.loc[carnitas, 'Burrito'] = 'Carnitas'
df.loc[~california & ~asada & ~surf & ~carnitas, 'Burrito'] = 'Other'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
# Drop some high cardinality categoricals
df = df.drop(columns=['Notes', 'Location', 'Reviewer', 'Address', 'URL', 'Neighborhood'])

# %%
# Drop some columns to prevent "leakage"
df = df.drop(columns=['Rec', 'overall'])

# %%
df.dtypes#Datetime object was giving me problems
# Out:
# Burrito            object
# Yelp              float64
# Google            float64
# Chips              object
# Cost              float64
# Hunger            float64
# Mass (g)          float64
# Density (g/mL)    float64
# Length            float64
# Circum            float64
# Volume            float64
# Tortilla          float64
# Temp              float64
# Meat              float64
# Fillings          float64
# Meat:filling      float64
# Uniformity        float64
# Salsa             float64
# Synergy           float64
# Wrap              float64
# Unreliable         object
# NonSD              object
# Beef               object
# Pico               object
# Guac               object
# Cheese             object
# Fries              object
# Sour cream         object
# Pork               object
# Chicken            object
# Shrimp             object
# Fish               object
# Rice               object
# Beans              object
# Lettuce            object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 421 entries, 2016-01-18 to 2019-08-27
# Data columns (total 58 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Burrito         421 non-null    object
#  1   Yelp            87 non-null     float64
#  2   Google          87 non-null     float64
#  3   Chips           26 non-null     object
#  4   Cost            414 non-null    float64
#  5   Hunger          418 non-null    float64
#  6   Mass (g)        22 non-null     float64
#  7   Density (g/mL)  22 non-null     float64
#  8   Length          283 non-null    float64
#  9   Circum          281 non-null    float64
#  10  Volume          281 non-null    float64
#  11  Tortilla        421 non-null    float64
#  12  Temp            401 non-null    float64
#  13  Meat            407 non-null    float64
#  14  Fillings        418 non-null    float64
#  15  Meat:filling    412 non-null    float64
# ...

# %%
df['Mass (g)'].isnull().values.sum()
# Out:
# 399

# %%
df.drop(columns=['Queso','Ham','Carrots','Lobster', 'Zucchini','Corn','Sushi','Mushroom', 'Bacon',
                 'Taquito','Fish', 'Tomato', 'Bell peper', 'Chile relleno', 'Nopales', 'Lobster', 'Mass (g)', 'Density (g/mL)'])
# Out:
#                Burrito  Yelp  Google Chips  ...  Pineapple  Egg  Avocado  Great
# Date                                        ...
# 2016-01-18  California   3.5     4.2   NaN  ...        NaN  NaN      NaN  False
# 2016-01-24  California   3.5     3.3   NaN  ...        NaN  NaN      NaN  False
# 2016-01-24    Carnitas   NaN     NaN   NaN  ...        NaN  NaN      NaN  False
# 2016-01-24       Asada   NaN     NaN   NaN  ...        NaN  NaN      NaN  False
# 2016-01-27  California   4.0     3.8     x  ...        NaN  NaN      NaN   True
# ...                ...   ...     ...   ...  ...        ...  ...      ...    ...
# 2019-08-27       Other   NaN     NaN   NaN  ...        NaN  NaN      NaN  False
# 2019-08-27       Other   NaN     NaN   NaN  ...        NaN  NaN      NaN   True
# 2019-08-27  California   NaN     NaN   NaN  ...        NaN  NaN      NaN  False
# 2019-08-27       Other   NaN     NaN   NaN  ...        NaN  NaN      NaN   True
# ...

# %%
df.describe(include='all')
# Out:
#            Burrito       Yelp     Google Chips  ...  Avocado  Corn  Zucchini  Great
# count          421  87.000000  87.000000    26  ...       13     3         1    421
# unique           5        NaN        NaN     4  ...        1     2         1      2
# top     California        NaN        NaN     x  ...        x     x         x  False
# freq           169        NaN        NaN    21  ...       13     2         1    239
# mean           NaN   3.887356   4.167816   NaN  ...      NaN   NaN       NaN    NaN
# std            NaN   0.475396   0.373698   NaN  ...      NaN   NaN       NaN    NaN
# min            NaN   2.500000   2.900000   NaN  ...      NaN   NaN       NaN    NaN
# 25%            NaN   3.500000   4.000000   NaN  ...      NaN   NaN       NaN    NaN
# 50%            NaN   4.000000   4.200000   NaN  ...      NaN   NaN       NaN    NaN
# 75%            NaN   4.000000   4.400000   NaN  ...      NaN   NaN       NaN    NaN
# ...

# %%
#df.dropna

# %%
df.fillna(0)
# Out:
#                Burrito  Yelp  Google Chips  ...  Avocado  Corn  Zucchini  Great
# Date                                        ...
# 2016-01-18  California   3.5     4.2     0  ...        0     0         0  False
# 2016-01-24  California   3.5     3.3     0  ...        0     0         0  False
# 2016-01-24    Carnitas   0.0     0.0     0  ...        0     0         0  False
# 2016-01-24       Asada   0.0     0.0     0  ...        0     0         0  False
# 2016-01-27  California   4.0     3.8     x  ...        0     0         0   True
# ...                ...   ...     ...   ...  ...      ...   ...       ...    ...
# 2019-08-27       Other   0.0     0.0     0  ...        0     0         0  False
# 2019-08-27       Other   0.0     0.0     0  ...        0     0         0   True
# 2019-08-27  California   0.0     0.0     0  ...        0     0         0  False
# 2019-08-27       Other   0.0     0.0     0  ...        0     0         0   True
# ...

# %%
cutoff_1 = '01/01/2017'
cutoff_2 = '01/01/2018'
mask_1 = df.index < cutoff_2

# %%
train_val = df.loc[mask_1]
test = df.loc[~mask_1]
df.shape, train_val.shape, test.shape
# Out:
# ((421, 58), (383, 58), (38, 58))

# %%
train_val.head()
# Out:
#                Burrito  Yelp  Google Chips  ...  Avocado  Corn  Zucchini  Great
# Date                                        ...
# 2016-01-18  California   3.5     4.2   NaN  ...      NaN   NaN       NaN  False
# 2016-01-24  California   3.5     3.3   NaN  ...      NaN   NaN       NaN  False
# 2016-01-24    Carnitas   NaN     NaN   NaN  ...      NaN   NaN       NaN  False
# 2016-01-24       Asada   NaN     NaN   NaN  ...      NaN   NaN       NaN  False
# 2016-01-27  California   4.0     3.8     x  ...      NaN   NaN       NaN   True
#
# [5 rows x 58 columns]

# %%
mask_2 = train_val.index < cutoff_1

# %%
#train_val = train_val.copy()

# %%
train = train_val.loc[mask_2]
val = train_val.loc[~mask_2]
assert (len(train) + len(test) + len(val))==len(df)#Sanity check
train.shape, val.shape, test.shape
# Out:
# ((298, 58), (85, 58), (38, 58))

# %%
#assert (len(train)+len(val))==len(df)#Sanity check

# %%
from sklearn.model_selection import train_test_split

# %%
train.head()
# Out:
#                Burrito  Yelp  Google Chips  ...  Avocado  Corn  Zucchini  Great
# Date                                        ...
# 2016-01-18  California   3.5     4.2   NaN  ...      NaN   NaN       NaN  False
# 2016-01-24  California   3.5     3.3   NaN  ...      NaN   NaN       NaN  False
# 2016-01-24    Carnitas   NaN     NaN   NaN  ...      NaN   NaN       NaN  False
# 2016-01-24       Asada   NaN     NaN   NaN  ...      NaN   NaN       NaN  False
# 2016-01-27  California   4.0     3.8     x  ...      NaN   NaN       NaN   True
#
# [5 rows x 58 columns]

# %%
target = 'Great'
X_train = train.drop(columns=[target])
y_train = train[target]
X_val = val.drop(columns=[target])
y_val = val[target]
X_test = test.drop(columns=[target])
y_test = test[target]

# %% [markdown]
# Baseline (Majority)

# %%
y_train.value_counts(normalize=True)
# Out:
# False    0.590604
# True     0.409396
# Name: Great, dtype: float64

# %%
majority_class = y_train.value_counts(normalize=True).max()
majority_class
# Out:
# 0.5906040268456376

# %%
print('Baseline accuracy:', majority_class)
# Out:
# Baseline accuracy: 0.5906040268456376

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
plt.scatter(X_train['Hunger'], y_train)
plt.yticks(np.arange(0,1.1,0.2))
plt.xlabel('Hunger')
plt.ylabel('Great');

# %% [markdown]
# # **Build Model and Stretch Goals**

# %%
'''
# What goes in model
One-hot encoder
Simple Imputer
Standard Scaler
Logistic Regression
#What to import from: category_encoders, preprocessing(sklearn), impute, pipeline,
make_pipeline, linear_model, import LogisticRegression
'''
# Out:
# '\n# What goes in model\nOne-hot encoder\nSimple Imputer\nStandard Scaler\nLogistic Regression\n#What to import from: category_encoders, preprocessing(sklearn), impute, pipeline,\nmake_pipeline, linear_model, import LogisticRegression\n'

# %%
import category_encoders as ce
from category_encoders import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
import numpy as np

# %%
model = make_pipeline(
    OneHotEncoder(use_cat_names=True),
    SimpleImputer(strategy='mean'),
    StandardScaler(),
    LogisticRegression()   
)

# %%
model.fit(X_train, y_train);
# Out:
# /usr/local/lib/python3.6/dist-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
model.named_steps['onehotencoder'].get_feature_names()
# Out:
# ['Burrito_California',
#  'Burrito_Carnitas',
#  'Burrito_Asada',
#  'Burrito_Other',
#  'Burrito_Surf & Turf',
#  'Yelp',
#  'Google',
#  'Chips_nan',
#  'Chips_x',
#  'Chips_X',
#  'Cost',
#  'Hunger',
#  'Mass (g)',
#  'Density (g/mL)',
#  'Length',
#  'Circum',
#  'Volume',
#  'Tortilla',
#  'Temp',
#  'Meat',
#  'Fillings',
#  'Meat:filling',
#  'Uniformity',
#  'Salsa',
#  'Synergy',
#  'Wrap',
#  'Unreliable_nan',
#  'Unreliable_x',
#  'NonSD_nan',
#  'NonSD_x',
#  'NonSD_X',
#  'Beef_x',
#  'Beef_nan',
#  'Beef_X',
#  'Pico_x',
#  'Pico_nan',
#  'Pico_X',
#  'Guac_x',
#  'Guac_nan',
#  'Guac_X',
#  'Cheese_x',
#  'Cheese_nan',
#  'Cheese_X',
#  'Fries_x',
#  'Fries_nan',
#  'Fries_X',
#  'Sour cream_nan',
#  'Sour cream_x',
#  'Sour cream_X',
#  'Pork_nan',
#  'Pork_x',
#  'Pork_X',
#  'Chicken_nan',
#  'Chicken_x',
#  'Chicken_X',
#  'Shrimp_nan',
#  'Shrimp_x',
#  'Shrimp_X',
#  'Fish_nan',
#  'Fish_x',
#  'Fish_X',
#  'Rice_nan',
#  'Rice_x',
#  'Rice_X',
#  'Beans_nan',
# ...

# %%
print('Training Accuracy:', model.score(X_train,y_train))
# Out:
# Training Accuracy: 0.9362416107382551

# %%
print('Validation Accuracy:', model.score(X_val,y_val))
# Out:
# Validation Accuracy: 0.7647058823529411

# %%
print('Test Accuracy:', model.score(X_test, y_test))
# Out:
# Test Accuracy: 0.7631578947368421

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import r2_score

# %%
# One way...
y_pred = model.predict(X_val)
accuracy_score(y_val, y_pred)
#No change after dropping null values
# Out:
# 0.7647058823529411

# %%
'''
X_train = X_train.fillna(0)
y_train = y_train.fillna(0)
X_val = X_val.fillna(0) 
y_val = y_val.fillna(0)
X_test = X_test.fillna(0)
y_test = y_test.fillna(0)
'''
# Out:
# '\nX_train = X_train.fillna(0)\ny_train = y_train.fillna(0)\nX_val = X_val.fillna(0) \ny_val = y_val.fillna(0)\nX_test = X_test.fillna(0)\ny_test = y_test.fillna(0)\n'

# %%
'''
X_train = X_train.dropna
y_train = y_train.dropna
X_val = X_val.dropna
y_val = y_val.dropna
X_test = X_test.dropna
y_test = y_test.dropna
'''
# Out:
# '\nX_train = X_train.dropna\ny_train = y_train.dropna\nX_val = X_val.dropna\ny_val = y_val.dropna\nX_test = X_test.dropna\ny_test = y_test.dropna\n'

# %%
print('Training Accuracy:', model.score(X_train,y_train))
# Out:
# Training Accuracy: 0.9362416107382551

# %%
# display that as a graphic.
import seaborn as sns
sns.countplot(y_train);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# display that as a graphic.
import seaborn as sns
sns.countplot(y_test);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# display that as a graphic.
import seaborn as sns
sns.countplot(y_pred);
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
model.fit(X_train, y_train);
# Out:
# /usr/local/lib/python3.6/dist-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
y_pred.shape
# Out:
# (85,)

# %%
y_val.shape
# Out:
# (85,)

# %%
test.shape
# Out:
# (38, 58)

# %%
X_test.shape
# Out:
# (38, 57)

# %%
#accuracy_score(X_test, y_pred)  Did not work

# %%
log_reg = LogisticRegression()

# %%
#log_reg.coef_[0]

# %%
#I had trouble getting coefficients
#%matplotlib inline
#coefficients = pd.Series(model.coef_[0], X_train.columns)
#coefficients.sort_values().plot.barh(); #bar charts
#here we can see the true effect of coefficient compared with others because the data is scaled 
#women and children first hypothesis is true ... if you were a female you had a higher probability to survive
